# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rn

# %%
dataset1 = pd.read_csv('AirQuality.csv', sep = ";")
dataset2 = pd.read_csv('heart.csv')

# %%
dataset1.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %%
dataset2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Data Cleaning

# %%
# To check for missing values in the entire dataset:
dataset1.isnull()
# Out:
#        Date   Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     False  False   False        False     False     False          False
# 1     False  False   False        False     False     False          False
# 2     False  False   False        False     False     False          False
# 3     False  False   False        False     False     False          False
# 4     False  False   False        False     False     False          False
# ...     ...    ...     ...          ...       ...       ...            ...
# 9466   True   True    True         True      True      True           True
# 9467   True   True    True         True      True      True           True
# 9468   True   True    True         True      True      True           True
# 9469   True   True    True         True      True      True           True
# 9470   True   True    True         True      True      True           True
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T     RH  \
# 0       False         False    False         False        False  False  False
# 1       False         False    False         False        False  False  False
# 2       False         False    False         False        False  False  False
# 3       False         False    False         False        False  False  False
# 4       False         False    False         False        False  False  False
# ...       ...           ...      ...           ...          ...    ...    ...
# 9466     True          True     True          True         True   True   True
# 9467     True          True     True          True         True   True   True
# 9468     True          True     True          True         True   True   True
# 9469     True          True     True          True         True   True   True
# 9470     True          True     True          True         True   True   True
#
#          AH  Unnamed: 15  Unnamed: 16
# 0     False         True         True
# 1     False         True         True
# 2     False         True         True
# 3     False         True         True
# 4     False         True         True
# ...     ...          ...          ...
# 9466   True         True         True
# 9467   True         True         True
# 9468   True         True         True
# 9469   True         True         True
# 9470   True         True         True
#
# [9471 rows x 17 columns]

# %%
# To check the sum of null values in columns
dataset1.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
# To drop rows with missing values
dataset1.dropna()
# Out:
# Empty DataFrame
# Columns: [Date, Time, CO(GT), PT08.S1(CO), NMHC(GT), C6H6(GT), PT08.S2(NMHC), NOx(GT), PT08.S3(NOx), NO2(GT), PT08.S4(NO2), PT08.S5(O3), T, RH, AH, Unnamed: 15, Unnamed: 16]
# Index: []

# %%
# Removing duplicates
dataset1.drop_duplicates()
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9357         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
# 9357            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9353       1269.0  24,3  23,7  0,7119          NaN          NaN
# 9354       1092.0  26,9  18,3  0,6406          NaN          NaN
# 9355        770.0  28,3  13,5  0,5139          NaN          NaN
# 9356        816.0  28,5  13,1  0,5028          NaN          NaN
# 9357          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9358 rows x 17 columns]

# %% [markdown]
# # Data Integration

# %%
#Data Integration
integration1 = dataset1.loc[111:999, ['Date', 'Time', 'C6H6(GT)', 'RH']]

# %%
integration2 = dataset1.iloc[[1,3,5,2,4,22,43,54,67,7,8,9,50,10,11]]

# %%
dataset1_integration = pd.concat([integration1, integration2])

# %%
dataset1_integration
# Out:
#            Date      Time C6H6(GT)    RH CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# 111  15/03/2004  09.00.00     36,7  54,3    NaN          NaN       NaN
# 112  15/03/2004  10.00.00     26,6  45,6    NaN          NaN       NaN
# 113  15/03/2004  11.00.00     20,1  38,5    NaN          NaN       NaN
# 114  15/03/2004  12.00.00     14,1  34,1    NaN          NaN       NaN
# 115  15/03/2004  13.00.00     14,9  32,2    NaN          NaN       NaN
# ..          ...       ...      ...   ...    ...          ...       ...
# 8    11/03/2004  02.00.00      2,3  59,7    0,9       1094.0      24.0
# 9    11/03/2004  03.00.00      1,7  60,2    0,6       1010.0      19.0
# 50   12/03/2004  20.00.00     32,6  50,5    6,6       1843.0     488.0
# 10   11/03/2004  04.00.00      1,3  60,5   -200       1011.0      14.0
# 11   11/03/2004  05.00.00      1,1  56,2    0,7       1066.0       8.0
#
#      PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 111            NaN      NaN           NaN      NaN           NaN          NaN
# 112            NaN      NaN           NaN      NaN           NaN          NaN
# 113            NaN      NaN           NaN      NaN           NaN          NaN
# 114            NaN      NaN           NaN      NaN           NaN          NaN
# 115            NaN      NaN           NaN      NaN           NaN          NaN
# ..             ...      ...           ...      ...           ...          ...
# 8            609.0     45.0        1579.0     60.0        1276.0        620.0
# 9            561.0   -200.0        1705.0   -200.0        1235.0        501.0
# 50          1610.0    340.0         624.0    170.0        2390.0       1887.0
# 10           527.0     21.0        1818.0     34.0        1197.0        445.0
# 11           512.0     16.0        1918.0     28.0        1182.0        422.0
#
#         T      AH  Unnamed: 15  Unnamed: 16
# 111   NaN     NaN          NaN          NaN
# 112   NaN     NaN          NaN          NaN
# 113   NaN     NaN          NaN          NaN
# 114   NaN     NaN          NaN          NaN
# 115   NaN     NaN          NaN          NaN
# ..    ...     ...          ...          ...
# 8    10,7  0,7648          NaN          NaN
# 9    10,3  0,7517          NaN          NaN
# 50   12,9  0,7478          NaN          NaN
# 10   10,1  0,7465          NaN          NaN
# 11   11,0  0,7366          NaN          NaN
#
# [904 rows x 17 columns]

# %% [markdown]
# # Data Transformation

# %%
dataset1_integration.transpose()
# Out:
#                       111         112         113         114         115  \
# Date           15/03/2004  15/03/2004  15/03/2004  15/03/2004  15/03/2004
# Time             09.00.00    10.00.00    11.00.00    12.00.00    13.00.00
# C6H6(GT)             36,7        26,6        20,1        14,1        14,9
# RH                   54,3        45,6        38,5        34,1        32,2
# CO(GT)                NaN         NaN         NaN         NaN         NaN
# PT08.S1(CO)           NaN         NaN         NaN         NaN         NaN
# NMHC(GT)              NaN         NaN         NaN         NaN         NaN
# PT08.S2(NMHC)         NaN         NaN         NaN         NaN         NaN
# NOx(GT)               NaN         NaN         NaN         NaN         NaN
# PT08.S3(NOx)          NaN         NaN         NaN         NaN         NaN
# NO2(GT)               NaN         NaN         NaN         NaN         NaN
# PT08.S4(NO2)          NaN         NaN         NaN         NaN         NaN
# PT08.S5(O3)           NaN         NaN         NaN         NaN         NaN
# T                     NaN         NaN         NaN         NaN         NaN
# AH                    NaN         NaN         NaN         NaN         NaN
# Unnamed: 15           NaN         NaN         NaN         NaN         NaN
# Unnamed: 16           NaN         NaN         NaN         NaN         NaN
#
#                       116         117         118         119         120  \
# Date           15/03/2004  15/03/2004  15/03/2004  15/03/2004  15/03/2004
# Time             14.00.00    15.00.00    16.00.00    17.00.00    18.00.00
# C6H6(GT)             15,4        12,1        11,5        14,8        32,1
# RH                   30,0        28,9        29,4        31,3        35,4
# CO(GT)                NaN         NaN         NaN         NaN         NaN
# PT08.S1(CO)           NaN         NaN         NaN         NaN         NaN
# NMHC(GT)              NaN         NaN         NaN         NaN         NaN
# PT08.S2(NMHC)         NaN         NaN         NaN         NaN         NaN
# NOx(GT)               NaN         NaN         NaN         NaN         NaN
# PT08.S3(NOx)          NaN         NaN         NaN         NaN         NaN
# NO2(GT)               NaN         NaN         NaN         NaN         NaN
# PT08.S4(NO2)          NaN         NaN         NaN         NaN         NaN
# PT08.S5(O3)           NaN         NaN         NaN         NaN         NaN
# T                     NaN         NaN         NaN         NaN         NaN
# AH                    NaN         NaN         NaN         NaN         NaN
# Unnamed: 15           NaN         NaN         NaN         NaN         NaN
# Unnamed: 16           NaN         NaN         NaN         NaN         NaN
#
#                ...         22          43          54          67   \
# Date           ...  11/03/2004  12/03/2004  13/03/2004  13/03/2004
# Time           ...    16.00.00    13.00.00    00.00.00    13.00.00
# C6H6(GT)       ...         8,3        11,0         9,6        12,3
# RH             ...        71,2        34,5        64,1        31,3
# CO(GT)         ...         2,2         2,5         2,7         2,8
# PT08.S1(CO)    ...      1292.0      1252.0      1280.0      1328.0
# NMHC(GT)       ...        95.0       140.0       122.0       154.0
# PT08.S2(NMHC)  ...       912.0      1016.0       964.0      1059.0
# NOx(GT)        ...       193.0       160.0       193.0       153.0
# PT08.S3(NOx)   ...      1103.0      1008.0       963.0       987.0
# NO2(GT)        ...       131.0       116.0       113.0       124.0
# PT08.S4(NO2)   ...      1591.0      1593.0      1544.0      1600.0
# PT08.S5(O3)    ...       957.0       983.0      1285.0      1101.0
# T              ...         9,7        16,1         9,5        19,4
# AH             ...      0,8569      0,6262      0,7597      0,6950
# Unnamed: 15    ...         NaN         NaN         NaN         NaN
# Unnamed: 16    ...         NaN         NaN         NaN         NaN
#
#                       7           8           9           50          10   \
# Date           11/03/2004  11/03/2004  11/03/2004  12/03/2004  11/03/2004
# Time             01.00.00    02.00.00    03.00.00    20.00.00    04.00.00
# C6H6(GT)              3,3         2,3         1,7        32,6         1,3
# RH                   60,0        59,7        60,2        50,5        60,5
# CO(GT)                  1         0,9         0,6         6,6        -200
# PT08.S1(CO)        1136.0      1094.0      1010.0      1843.0      1011.0
# NMHC(GT)             31.0        24.0        19.0       488.0        14.0
# PT08.S2(NMHC)       672.0       609.0       561.0      1610.0       527.0
# NOx(GT)              62.0        45.0      -200.0       340.0        21.0
# PT08.S3(NOx)       1453.0      1579.0      1705.0       624.0      1818.0
# NO2(GT)              76.0        60.0      -200.0       170.0        34.0
# PT08.S4(NO2)       1333.0      1276.0      1235.0      2390.0      1197.0
# PT08.S5(O3)         730.0       620.0       501.0      1887.0       445.0
# T                    10,7        10,7        10,3        12,9        10,1
# AH                 0,7702      0,7648      0,7517      0,7478      0,7465
# Unnamed: 15           NaN         NaN         NaN         NaN         NaN
# Unnamed: 16           NaN         NaN         NaN         NaN         NaN
#
#                       11
# Date           11/03/2004
# Time             05.00.00
# C6H6(GT)              1,1
# RH                   56,2
# CO(GT)                0,7
# PT08.S1(CO)        1066.0
# NMHC(GT)              8.0
# PT08.S2(NMHC)       512.0
# NOx(GT)              16.0
# PT08.S3(NOx)       1918.0
# NO2(GT)              28.0
# PT08.S4(NO2)       1182.0
# PT08.S5(O3)         422.0
# T                    11,0
# AH                 0,7366
# Unnamed: 15           NaN
# Unnamed: 16           NaN
#
# [17 rows x 904 columns]

# %%
dataset1.drop(columns = "NOx(GT)")
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T  \
# 0            1046.0        1056.0    113.0        1692.0       1268.0  13,6
# 1             955.0        1174.0     92.0        1559.0        972.0  13,3
# 2             939.0        1140.0    114.0        1555.0       1074.0  11,9
# 3             948.0        1092.0    122.0        1584.0       1203.0  11,0
# 4             836.0        1205.0    116.0        1490.0       1110.0  11,2
# ...             ...           ...      ...           ...          ...   ...
# 9466            NaN           NaN      NaN           NaN          NaN   NaN
# 9467            NaN           NaN      NaN           NaN          NaN   NaN
# 9468            NaN           NaN      NaN           NaN          NaN   NaN
# 9469            NaN           NaN      NaN           NaN          NaN   NaN
# 9470            NaN           NaN      NaN           NaN          NaN   NaN
#
#         RH      AH  Unnamed: 15  Unnamed: 16
# 0     48,9  0,7578          NaN          NaN
# 1     47,7  0,7255          NaN          NaN
# 2     54,0  0,7502          NaN          NaN
# 3     60,0  0,7867          NaN          NaN
# 4     59,6  0,7888          NaN          NaN
# ...    ...     ...          ...          ...
# 9466   NaN     NaN          NaN          NaN
# 9467   NaN     NaN          NaN          NaN
# 9468   NaN     NaN          NaN          NaN
# 9469   NaN     NaN          NaN          NaN
# 9470   NaN     NaN          NaN          NaN
#
# [9471 rows x 16 columns]

# %%
dataset1.drop(1)
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# 5     10/03/2004  23.00.00    1,2       1197.0      38.0      4,7
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# 5             750.0     89.0        1337.0     96.0        1393.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# 5           949.0  11,2  59,2  0,7848          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9470 rows x 17 columns]

# %% [markdown]
# # Data Transformation Error Correcting

# %%
dataset1
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
# data transformation and error correcting
dataset1.rename(columns={'T':'Temperature','RH':'Humidity'},inplace=True)
dataset1.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3) Temperature  \
# 0    166.0        1056.0    113.0        1692.0       1268.0        13,6
# 1    103.0        1174.0     92.0        1559.0        972.0        13,3
# 2    131.0        1140.0    114.0        1555.0       1074.0        11,9
# 3    172.0        1092.0    122.0        1584.0       1203.0        11,0
# 4    131.0        1205.0    116.0        1490.0       1110.0        11,2
#
#   Humidity      AH  Unnamed: 15  Unnamed: 16
# 0     48,9  0,7578          NaN          NaN
# 1     47,7  0,7255          NaN          NaN
# 2     54,0  0,7502          NaN          NaN
# 3     60,0  0,7867          NaN          NaN
# 4     59,6  0,7888          NaN          NaN

# %%
dataset1['Datetime'] = dataset1['Date'] + dataset1['Time']
dataset1.set_index('Datetime',inplace=True)
dataset1.head()
# Out:
#                           Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# Datetime
# 10/03/200418.00.00  10/03/2004  18.00.00    2,6       1360.0     150.0
# 10/03/200419.00.00  10/03/2004  19.00.00      2       1292.0     112.0
# 10/03/200420.00.00  10/03/2004  20.00.00    2,2       1402.0      88.0
# 10/03/200421.00.00  10/03/2004  21.00.00    2,2       1376.0      80.0
# 10/03/200422.00.00  10/03/2004  22.00.00    1,6       1272.0      51.0
#
#                    C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# Datetime
# 10/03/200418.00.00     11,9         1046.0    166.0        1056.0    113.0
# 10/03/200419.00.00      9,4          955.0    103.0        1174.0     92.0
# 10/03/200420.00.00      9,0          939.0    131.0        1140.0    114.0
# 10/03/200421.00.00      9,2          948.0    172.0        1092.0    122.0
# 10/03/200422.00.00      6,5          836.0    131.0        1205.0    116.0
#
#                     PT08.S4(NO2)  PT08.S5(O3) Temperature Humidity      AH  \
# Datetime
# 10/03/200418.00.00        1692.0       1268.0        13,6     48,9  0,7578
# 10/03/200419.00.00        1559.0        972.0        13,3     47,7  0,7255
# 10/03/200420.00.00        1555.0       1074.0        11,9     54,0  0,7502
# 10/03/200421.00.00        1584.0       1203.0        11,0     60,0  0,7867
# 10/03/200422.00.00        1490.0       1110.0        11,2     59,6  0,7888
#
#                     Unnamed: 15  Unnamed: 16
# Datetime
# 10/03/200418.00.00          NaN          NaN
# 10/03/200419.00.00          NaN          NaN
# 10/03/200420.00.00          NaN          NaN
# 10/03/200421.00.00          NaN          NaN
# 10/03/200422.00.00          NaN          NaN

# %% [markdown]
# # Data Integration

# %%
# data integration 
#making subset of air quality dataset to show data integration
air_subset1 = dataset1[['Date','Time','CO(GT)','PT08.S1(CO)','Temperature']]
air_subset2 = dataset1[['Temperature','Humidity','AH']]

# %%
air_subset1.head()
# Out:
#                           Date      Time CO(GT)  PT08.S1(CO) Temperature
# Datetime
# 10/03/200418.00.00  10/03/2004  18.00.00    2,6       1360.0        13,6
# 10/03/200419.00.00  10/03/2004  19.00.00      2       1292.0        13,3
# 10/03/200420.00.00  10/03/2004  20.00.00    2,2       1402.0        11,9
# 10/03/200421.00.00  10/03/2004  21.00.00    2,2       1376.0        11,0
# 10/03/200422.00.00  10/03/2004  22.00.00    1,6       1272.0        11,2

# %%
air_subset2.head()
# Out:
#                    Temperature Humidity      AH
# Datetime
# 10/03/200418.00.00        13,6     48,9  0,7578
# 10/03/200419.00.00        13,3     47,7  0,7255
# 10/03/200420.00.00        11,9     54,0  0,7502
# 10/03/200421.00.00        11,0     60,0  0,7867
# 10/03/200422.00.00        11,2     59,6  0,7888

# %%
integrated_data = pd.merge(air_subset1,air_subset2,on='Temperature')
integrated_data.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO) Temperature Humidity      AH
# 0  10/03/2004  18.00.00    2,6       1360.0        13,6     48,9  0,7578
# 1  10/03/2004  18.00.00    2,6       1360.0        13,6     62,1  0,9636
# 2  10/03/2004  18.00.00    2,6       1360.0        13,6     56,3  0,8743
# 3  10/03/2004  18.00.00    2,6       1360.0        13,6     58,8  0,9120
# 4  10/03/2004  18.00.00    2,6       1360.0        13,6     55,1  0,8560

# %% [markdown]
# # Data Model Building

# %%
# data model building
dataset2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dataset2.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
y = dataset2[['target']]
x = dataset2.drop(y,axis = 1)
y.head(2)
# Out:
#    target
# 0       0
# 1       0

# %%
y['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((820, 13), (205, 13), (820, 1), (205, 1))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
#predecting on test data
model = LogisticRegression()
model = LogisticRegression(max_iter=1000) 
model.fit(x_train, y_train)
y_test['Prediction'] = model.predict(x_test)
# Out:
# /home/aniket/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
